# %%
tesString = "dicoding"
tesString.upper()
# Out:
# 'DICODING'

# %%
tesString.lower()
# Out:
# 'dicoding'

# %%
tesString.title()
# Out:
# 'Dicoding'

# %%
tesString.split('i')
# Out:
# ['d', 'cod', 'ng']

# %%
tesString.zfill(20)
# Out:
# '000000000000dicoding'
